# %% [markdown]
# <a href="https://colab.research.google.com/github/mohkaow/AIML101/blob/master/109_query_thai_stock.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img height="45px" src="https://avatars3.githubusercontent.com/u/20337240?s=460&v=4" align="left" hspace="10px" vspace="0px">
#
# <h1>ตัวอย่างการดูข้อมูลหุ้นไทย</h1>
#
# <hr>

# %% [markdown]
# # ติดตั้งแพ็กเกจ และเซทอัพ Environment

# %%
# !pip install pandas_datareader
# Out:
# Requirement already satisfied: pandas_datareader in /usr/local/lib/python3.6/dist-packages (0.7.4)
# Requirement already satisfied: lxml in /usr/local/lib/python3.6/dist-packages (from pandas_datareader) (4.2.6)
# Requirement already satisfied: requests>=2.3.0 in /usr/local/lib/python3.6/dist-packages (from pandas_datareader) (2.21.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.6/dist-packages (from pandas_datareader) (1.11.2)
# Requirement already satisfied: pandas>=0.19.2 in /usr/local/lib/python3.6/dist-packages (from pandas_datareader) (0.25.3)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests>=2.3.0->pandas_datareader) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests>=2.3.0->pandas_datareader) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests>=2.3.0->pandas_datareader) (2019.11.28)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests>=2.3.0->pandas_datareader) (1.24.3)
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.19.2->pandas_datareader) (2.6.1)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.19.2->pandas_datareader) (1.17.5)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.19.2->pandas_datareader) (2018.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.6/dist-packages (from python-dateutil>=2.6.1->pandas>=0.19.2->pandas_datareader) (1.12.0)

# %%
import os, sys
import numpy as np
import pandas as pd
#pd.core.common.is_list_like = pd.api.types.is_list_like

from pandas_datareader import data as pdr
from tqdm import tqdm, trange

import matplotlib.pyplot as plt
import pandas as pd
from IPython.core.display import display, HTML

display(HTML("<style>.container { width:90% !important; }</style>"))
pd.options.display.max_columns = 999
pd.options.display.max_rows = 999
# Out:
# <style>.container { width:90% !important; }</style>

# %% [markdown]
# # ดูข้อมูลหุ้น

# %%
#@title ป้อนชื่อย่อหุ้นไทย (ในรูปแบบแอเรย์ ) และวันที่เริ่มต้นและสิ้นสุด
stock_list =  ['KBANK', 'SCB', 'BBL', 'KTB', 'AOT', 'PTT'] #@param {type:"raw"}
start_date = "2017-08-27" #@param {type:"date"}
end_date = "2020-01-09" #@param {type:"date"}

# %% [markdown]
# ## ดาวน์โหลดข้อมูลหุ้นไทย

# %%
data = {}
for quote in tqdm(stock_list):
    try:
        data[quote] = pdr.get_data_yahoo('{}.BK'.format(quote), start=start_date, end=end_date)        
    except:
        print("Error:", sys.exc_info()[0])
        print("Description:", sys.exc_info()[1])
# Out:
# 100%|██████████| 6/6 [00:02<00:00,  2.65it/s]

# %%
#temp = data['KBANK']
#temp.drop('Close',axis=1, inplace=True)
#temp.rename(columns={'Adj Close':'_Close'}, inplace=True)
#temp.to_csv('KBANK.csv')
#!cat KBANK.csv

# %% [markdown]
# ## ดูข้อมูลข้างใน (เลือกเฉพาะส่วนหัวมมาแสดง)

# %%
print("แสดงข้อมูลหุ้นบางส่วน", list(data.keys()))
[ df.head() for key, df in data.items()]
# Out:
# แสดงข้อมูลหุ้นบางส่วน ['KBANK', 'SCB', 'BBL', 'KTB', 'AOT', 'PTT']
# [             High    Low   Open  Close      Volume   Adj Close
#  Date
#  2017-08-28  201.0  196.0  198.5  200.0   9541900.0  191.377533
#  2017-08-29  204.0  198.0  199.0  203.0  13568500.0  194.248199
#  2017-08-30  205.0  202.0  203.0  205.0   6183400.0  196.161957
#  2017-08-31  205.0  200.0  204.0  201.0   6887500.0  192.334412
#  2017-09-01  206.0  202.0  203.0  204.0   6548200.0  195.205063,
#               High    Low   Open  Close      Volume   Adj Close
#  Date
#  2017-08-28  144.5  144.5  144.5  144.5    681800.0  131.757553
#  2017-08-29  149.0  144.0  144.5  148.5  24750900.0  135.404831
#  2017-08-30  152.0  149.5  150.5  150.5  15341000.0  137.228485
#  2017-08-31  151.5  149.5  150.5  150.5   9346300.0  137.228485
#  2017-09-01  152.0  150.5  151.0  151.0   5463700.0  137.684387,
#               High    Low   Open  Close     Volume   Adj Close
#  Date
#  2017-08-28  183.0  183.0  183.0  183.0   311700.0  171.510849
#  2017-08-29  187.5  182.5  183.0  186.0  8299000.0  174.322495
#  2017-08-30  187.5  186.0  187.0  186.0  3809900.0  174.322495
#  2017-08-31  186.5  184.0  186.0  184.5  3008000.0  172.916672
#  2017-09-01  187.5  184.5  185.0  186.0  4071000.0  174.322495,
#                   High        Low       Open      Close       Volume  Adj Close
#  Date
#  2017-08-28  18.200001  18.200001  18.200001  18.200001    2825200.0  16.942200
#  2017-08-29  19.000000  18.200001  18.200001  18.900000  108217600.0  17.593821
#  2017-08-30  19.000000  18.700001  19.000000  18.700001   33691400.0  17.407644
#  2017-08-31  18.799999  18.500000  18.700001  18.700001   52104900.0  17.407644
#  2017-09-01  18.799999  18.500000  18.700001  18.600000   37299700.0  17.314554,
#               High    Low   Open  Close      Volume  Adj Close
#  Date
#  2017-08-28  52.25  52.25  52.25  52.25   4063400.0  49.977715
#  2017-08-29  54.50  52.00  52.25  54.25  85814200.0  51.890736
#  2017-08-30  55.25  54.25  54.50  54.75  58396000.0  52.368992
#  2017-08-31  55.00  53.75  54.75  54.50  30605700.0  52.129864
#  2017-09-01  55.00  54.25  54.50  55.00  22029200.0  52.608120,
#                   High        Low       Open      Close       Volume  Adj Close
#  Date
#  2017-08-28  39.400002  39.400002  39.400002  39.400002    5629000.0  23.381756
#  2017-08-29  40.799999  39.299999  39.400002  40.000000  199823000.0  23.737823
#  2017-08-30  40.799999  40.000000  40.400002  40.200001   96940000.0  23.856512
#  2017-08-31  40.200001  39.400002  39.500000  39.900002   86320000.0  29.561327
#  2017-09-01  40.200001  39.799999  40.200001  40.000000   49800000.0  29.635420]

# %% [markdown]
# # พล็อตกราฟไล่เรียงหุ้นรายตัว

# %%
[ df.plot(y='Adj Close', label='Price', style='-r').set_title(key)  for key, df in data.items()]
# Out:
# [Text(0.5, 1.0, 'KBANK'),
#  Text(0.5, 1.0, 'SCB'),
#  Text(0.5, 1.0, 'BBL'),
#  Text(0.5, 1.0, 'KTB'),
#  Text(0.5, 1.0, 'AOT'),
#  Text(0.5, 1.0, 'PTT')]

# %% [markdown]
# # ฝากติดตาม
#
# <img height="20px" src="https://www.patanasongsivilai.com/blog/wp-content/uploads/2017/06/logo_facebook2.png" align="left" hspace="10px" vspace="0px">  https://www.facebook.com/programmerthai/
#
# <img height="14px" src="https://www.patanasongsivilai.com/blog/wp-content/uploads/2019/03/youtube.png" align="left" hspace="10px" vspace="3px">  https://www.youtube.com/channel/UCvhCKtG5cRE6K5--RJPql_w
